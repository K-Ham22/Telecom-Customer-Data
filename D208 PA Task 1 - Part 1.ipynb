# %% [markdown]
# # **D208 Predictive Modeling** | Performance Assessment Task 1 (file 1)
# ## **Churn Data Set**

# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
from statsmodels.formula.api import ols

# %%
from statsmodels.api import qqplot

# %%
from itertools import product

# %% [markdown]
# ### upload and clean churn data set

# %%
df= pd.read_csv('churn_clean.csv')
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b  \
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder  \
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  ...  MonthlyCharge Bandwidth_GB_Year Item1
# 0  99927  56.25100 -133.37571  ...     172.455519        904.536110     5  \
# 1  48661  44.32893  -84.24080  ...     242.632554        800.982766     3
# 2  97148  45.35589 -123.24657  ...     159.947583       2054.706961     4
# 3  92014  32.96687 -117.24798  ...     119.956840       2164.579412     4
# 4  77461  29.38012  -95.80673  ...     149.948316        271.493436     4
#
#   Item2  Item3  Item4  Item5 Item6 Item7 Item8
# 0     5      5      3      4     4     3     4
# 1     4      3      3      4     3     4     4
# 2     4      2      4      4     3     3     3
# 3     4      4      2      5     4     3     3
# 4     4      4      3      4     4     4     5
#
# [5 rows x 50 columns]

# %%
#drop columns: customer IDs and demographics
df.drop(columns=['CaseOrder', 'Customer_id', 'Interaction', 'UID', 'City', 'State', 'County', 'Zip', 'Lat', 'Lng', 'Area', 'TimeZone', 'Gender'], inplace=True)
df.head()
# Out:
#    Population                                Job  Children  Age    Income
# 0          38  Environmental health practitioner         0   68  28561.99  \
# 1       10446             Programmer, multimedia         1   27  21704.77
# 2        3735            Chief Financial Officer         4   50   9609.57
# 3       13863                          Solicitor         1   48  18925.23
# 4       11352                Medical illustrator         0   83  40074.19
#
#      Marital Churn  Outage_sec_perweek  Email  Contacts  ...  MonthlyCharge
# 0    Widowed    No            7.978323     10         0  ...     172.455519  \
# 1    Married   Yes           11.699080     12         0  ...     242.632554
# 2    Widowed    No           10.752800      9         0  ...     159.947583
# 3    Married    No           14.913540     15         2  ...     119.956840
# 4  Separated   Yes            8.147417     16         2  ...     149.948316
#
#   Bandwidth_GB_Year Item1 Item2 Item3 Item4 Item5 Item6 Item7 Item8
# 0        904.536110     5     5     5     3     4     4     3     4
# 1        800.982766     3     4     3     3     4     3     4     4
# 2       2054.706961     4     4     2     4     4     3     3     3
# 3       2164.579412     4     4     4     2     5     4     3     3
# 4        271.493436     4     4     4     3     4     4     4     5
#
# [5 rows x 37 columns]

# %%
#drop other columns

df.drop(columns=['Email', 'Contacts', 'Contract', 'DeviceProtection', 'TechSupport', 'PaperlessBilling', 'PaymentMethod', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5', 'Item6', 'Item7', 'Item8'], inplace=True)
df.head()
# Out:
#    Population                                Job  Children  Age    Income
# 0          38  Environmental health practitioner         0   68  28561.99  \
# 1       10446             Programmer, multimedia         1   27  21704.77
# 2        3735            Chief Financial Officer         4   50   9609.57
# 3       13863                          Solicitor         1   48  18925.23
# 4       11352                Medical illustrator         0   83  40074.19
#
#      Marital Churn  Outage_sec_perweek  Yearly_equip_failure Techie  ...
# 0    Widowed    No            7.978323                     1     No  ...  \
# 1    Married   Yes           11.699080                     1    Yes  ...
# 2    Widowed    No           10.752800                     1    Yes  ...
# 3    Married    No           14.913540                     0    Yes  ...
# 4  Separated   Yes            8.147417                     1     No  ...
#
#   InternetService Phone Multiple OnlineSecurity OnlineBackup StreamingTV
# 0     Fiber Optic   Yes       No            Yes          Yes          No  \
# 1     Fiber Optic   Yes      Yes            Yes           No         Yes
# 2             DSL   Yes      Yes             No           No          No
# 3             DSL   Yes       No            Yes           No         Yes
# 4     Fiber Optic    No       No             No           No         Yes
#
#   StreamingMovies     Tenure MonthlyCharge  Bandwidth_GB_Year
# 0             Yes   6.795513    172.455519         904.536110
# 1             Yes   1.156681    242.632554         800.982766
# 2             Yes  15.754144    159.947583        2054.706961
# 3              No  17.087227    119.956840        2164.579412
# 4              No   1.670972    149.948316         271.493436
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Preliminary Info on dataset

# %%
df.shape
# Out:
# (10000, 22)

# %%
df.dtypes
# Out:
# Population                int64
# Job                      object
# Children                  int64
# Age                       int64
# Income                  float64
# Marital                  object
# Churn                    object
# Outage_sec_perweek      float64
# Yearly_equip_failure      int64
# Techie                   object
# Port_modem               object
# Tablet                   object
# InternetService          object
# Phone                    object
# Multiple                 object
# OnlineSecurity           object
# OnlineBackup             object
# StreamingTV              object
# StreamingMovies          object
# Tenure                  float64
# MonthlyCharge           float64
# Bandwidth_GB_Year       float64
# dtype: object

# %%
df.describe()
# Out:
#           Population    Children           Age         Income
# count   10000.000000  10000.0000  10000.000000   10000.000000  \
# mean     9756.562400      2.0877     53.078400   39806.926771
# std     14432.698671      2.1472     20.698882   28199.916702
# min         0.000000      0.0000     18.000000     348.670000
# 25%       738.000000      0.0000     35.000000   19224.717500
# 50%      2910.500000      1.0000     53.000000   33170.605000
# 75%     13168.000000      3.0000     71.000000   53246.170000
# max    111850.000000     10.0000     89.000000  258900.700000
#
#        Outage_sec_perweek  Yearly_equip_failure        Tenure  MonthlyCharge
# count        10000.000000          10000.000000  10000.000000   10000.000000  \
# mean            10.001848              0.398000     34.526188     172.624816
# std              2.976019              0.635953     26.443063      42.943094
# min              0.099747              0.000000      1.000259      79.978860
# 25%              8.018214              0.000000      7.917694     139.979239
# 50%             10.018560              0.000000     35.430507     167.484700
# 75%             11.969485              1.000000     61.479795     200.734725
# max             21.207230              6.000000     71.999280     290.160419
#
#        Bandwidth_GB_Year
# count       10000.000000
# mean         3392.341550
# std          2185.294852
# min           155.506715
# 25%          1236.470827
# 50%          3279.536903
# 75%          5586.141370
# max          7158.981530

# %%
df.describe(include=object)
# Out:
#                               Job   Marital  Churn Techie Port_modem Tablet
# count                       10000     10000  10000  10000      10000  10000  \
# unique                        639         5      2      2          2      2
# top     Occupational psychologist  Divorced     No     No         No     No
# freq                           30      2092   7350   8321       5166   7009
#
#        InternetService  Phone Multiple OnlineSecurity OnlineBackup
# count             7871  10000    10000          10000        10000  \
# unique               2      2        2              2            2
# top        Fiber Optic    Yes       No             No           No
# freq              4408   9067     5392           6424         5494
#
#        StreamingTV StreamingMovies
# count        10000           10000
# unique           2               2
# top             No              No
# freq          5071            5110

# %%
# drop "Job" variable - too many unique observations
df.drop(columns='Job', inplace=True)

# %%
df.head()
# Out:
#    Population  Children  Age    Income    Marital Churn  Outage_sec_perweek
# 0          38         0   68  28561.99    Widowed    No            7.978323  \
# 1       10446         1   27  21704.77    Married   Yes           11.699080
# 2        3735         4   50   9609.57    Widowed    No           10.752800
# 3       13863         1   48  18925.23    Married    No           14.913540
# 4       11352         0   83  40074.19  Separated   Yes            8.147417
#
#    Yearly_equip_failure Techie Port_modem  ... InternetService Phone Multiple
# 0                     1     No        Yes  ...     Fiber Optic   Yes       No  \
# 1                     1    Yes         No  ...     Fiber Optic   Yes      Yes
# 2                     1    Yes        Yes  ...             DSL   Yes      Yes
# 3                     0    Yes         No  ...             DSL   Yes       No
# 4                     1     No        Yes  ...     Fiber Optic    No       No
#
#   OnlineSecurity OnlineBackup StreamingTV StreamingMovies     Tenure
# 0            Yes          Yes          No             Yes   6.795513  \
# 1            Yes           No         Yes             Yes   1.156681
# 2             No           No          No             Yes  15.754144
# 3            Yes           No         Yes              No  17.087227
# 4             No           No         Yes              No   1.670972
#
#    MonthlyCharge  Bandwidth_GB_Year
# 0     172.455519         904.536110
# 1     242.632554         800.982766
# 2     159.947583        2054.706961
# 3     119.956840        2164.579412
# 4     149.948316         271.493436
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (10000, 21)

# %%
df['Marital'].value_counts()
# Out:
# Marital
# Divorced         2092
# Widowed          2027
# Separated        2014
# Never Married    1956
# Married          1911
# Name: count, dtype: int64

# %%
# drop "Marital" variable - too many unique observations
df.drop(columns='Marital', inplace=True)
df.head()
# Out:
#    Population  Children  Age    Income Churn  Outage_sec_perweek
# 0          38         0   68  28561.99    No            7.978323  \
# 1       10446         1   27  21704.77   Yes           11.699080
# 2        3735         4   50   9609.57    No           10.752800
# 3       13863         1   48  18925.23    No           14.913540
# 4       11352         0   83  40074.19   Yes            8.147417
#
#    Yearly_equip_failure Techie Port_modem Tablet InternetService Phone
# 0                     1     No        Yes    Yes     Fiber Optic   Yes  \
# 1                     1    Yes         No    Yes     Fiber Optic   Yes
# 2                     1    Yes        Yes     No             DSL   Yes
# 3                     0    Yes         No     No             DSL   Yes
# 4                     1     No        Yes     No     Fiber Optic    No
#
#   Multiple OnlineSecurity OnlineBackup StreamingTV StreamingMovies     Tenure
# 0       No            Yes          Yes          No             Yes   6.795513  \
# 1      Yes            Yes           No         Yes             Yes   1.156681
# 2      Yes             No           No          No             Yes  15.754144
# 3       No            Yes           No         Yes              No  17.087227
# 4       No             No           No         Yes              No   1.670972
#
#    MonthlyCharge  Bandwidth_GB_Year
# 0     172.455519         904.536110
# 1     242.632554         800.982766
# 2     159.947583        2054.706961
# 3     119.956840        2164.579412
# 4     149.948316         271.493436

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.drop(columns='Children', inplace=True)
df.head()
# Out:
#    Population  Age    Income Churn  Outage_sec_perweek  Yearly_equip_failure
# 0          38   68  28561.99    No            7.978323                     1  \
# 1       10446   27  21704.77   Yes           11.699080                     1
# 2        3735   50   9609.57    No           10.752800                     1
# 3       13863   48  18925.23    No           14.913540                     0
# 4       11352   83  40074.19   Yes            8.147417                     1
#
#   Techie Port_modem Tablet InternetService Phone Multiple OnlineSecurity
# 0     No        Yes    Yes     Fiber Optic   Yes       No            Yes  \
# 1    Yes         No    Yes     Fiber Optic   Yes      Yes            Yes
# 2    Yes        Yes     No             DSL   Yes      Yes             No
# 3    Yes         No     No             DSL   Yes       No            Yes
# 4     No        Yes     No     Fiber Optic    No       No             No
#
#   OnlineBackup StreamingTV StreamingMovies     Tenure  MonthlyCharge
# 0          Yes          No             Yes   6.795513     172.455519  \
# 1           No         Yes             Yes   1.156681     242.632554
# 2           No          No             Yes  15.754144     159.947583
# 3           No         Yes              No  17.087227     119.956840
# 4           No         Yes              No   1.670972     149.948316
#
#    Bandwidth_GB_Year
# 0         904.536110
# 1         800.982766
# 2        2054.706961
# 3        2164.579412
# 4         271.493436

# %% [markdown]
# ### Check for null values

# %%
df.isna().sum()
# Out:
# Population                 0
# Age                        0
# Income                     0
# Churn                      0
# Outage_sec_perweek         0
# Yearly_equip_failure       0
# Techie                     0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                      0
# Multiple                   0
# OnlineSecurity             0
# OnlineBackup               0
# StreamingTV                0
# StreamingMovies            0
# Tenure                     0
# MonthlyCharge              0
# Bandwidth_GB_Year          0
# dtype: int64

# %% [markdown]
# #### no null values

# %% [markdown]
# ### CHeck for duplicate rows

# %%
df.duplicated().value_counts()
# Out:
# False    10000
# Name: count, dtype: int64

# %% [markdown]
# # Check for Outliers

# %% [markdown]
# ### **POPULATION**

# %%
sns.boxplot(x='Population', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Population'>

# %%
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

# %%
outliers = find_outliers_IQR(df['Population'])
print("number of outliers: " + str(len(outliers)))
print('max outlier value: ' + str(outliers.max()))
print('min outlier value: ' + str(outliers.min()))
# Out:
# number of outliers: 937
# max outlier value: 111850
# min outlier value: 31816

# %%
sns.histplot(x='Population', data=df)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %% [markdown]
# ### **AGE**

# %%
sns.boxplot(x='Age', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# no outliers in age

# %% [markdown]
# ### **INCOME**

# %%
sns.boxplot(x='Income', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Income'>

# %%
outliers = find_outliers_IQR(df['Income'])
print("number of outliers: " + str(len(outliers)))
print('max outlier value: ' + str(outliers.max()))
print('min outlier value: ' + str(outliers.min()))
# Out:
# number of outliers: 336
# max outlier value: 258900.7
# min outlier value: 104362.5

# %% [markdown]
# ### **OUTAGE_SEC_PERWEEK**

# %%
sns.boxplot(x='Outage_sec_perweek', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Outage_sec_perweek'>

# %%
outliers = find_outliers_IQR(df['Outage_sec_perweek'])
print("number of outliers: " + str(len(outliers)))
print('max outlier value: ' + str(outliers.max()))
print('min outlier value: ' + str(outliers.min()))
# Out:
# number of outliers: 76
# max outlier value: 21.20723
# min outlier value: 0.09974694

# %% [markdown]
# ### **YEARLY_EQUIP_FAILURE**

# %%
sns.boxplot(x='Yearly_equip_failure', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Yearly_equip_failure'>

# %%
outliers = find_outliers_IQR(df['Yearly_equip_failure'])
print("number of outliers: " + str(len(outliers)))
print('max outlier value: ' + str(outliers.max()))
print('min outlier value: ' + str(outliers.min()))
# Out:
# number of outliers: 94
# max outlier value: 6
# min outlier value: 3

# %% [markdown]
# ### **MONTHLYCHARGE**

# %%
sns.boxplot(x='MonthlyCharge', data=df, showmeans=True)
# Out:
# <Axes: xlabel='MonthlyCharge'>

# %% [markdown]
# ### **TENURE**

# %%
sns.boxplot(x='Tenure', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Tenure'>

# %% [markdown]
# # **OUTLIERS**
# - variables with outliers: Population, Income, Outage_sec_perweek, Yearly_equip_failture
# - if we remove all the rows with outliers in 'Population', about 10% of the data will be removed
# - will plot scatterplots against the target variable to see about outlier influence

# %%
sns.regplot(x='Population', y='Bandwidth_GB_Year', data=df, ci=None)
# Out:
# <Axes: xlabel='Population', ylabel='Bandwidth_GB_Year'>

# %%
sns.regplot(x='Income', y='Bandwidth_GB_Year', data=df, ci=None)
# Out:
# <Axes: xlabel='Income', ylabel='Bandwidth_GB_Year'>

# %%
sns.regplot(x='Outage_sec_perweek', y='Bandwidth_GB_Year', data=df, ci=None)
# Out:
# <Axes: xlabel='Outage_sec_perweek', ylabel='Bandwidth_GB_Year'>

# %%
sns.regplot(x='Yearly_equip_failure', y='Bandwidth_GB_Year', data=df, ci=None)
# Out:
# <Axes: xlabel='Yearly_equip_failure', ylabel='Bandwidth_GB_Year'>

# %% [markdown]
# - will drop data with 6 'yearly_equip_failures
# - will not drop any 'outage_sec_perweek' data
# - will drop income > 200,000
# - will drop population > 100,000

# %%
df.drop(df[df['Yearly_equip_failure'] == 6].index, inplace=True)

# %%
df.shape
# Out:
# (9999, 19)

# %%
df['Yearly_equip_failure'].describe()
# Out:
# count    9999.000000
# mean        0.397440
# std         0.633512
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         4.000000
# Name: Yearly_equip_failure, dtype: float64

# %%
df.drop(df[df['Income'] > 200000].index, inplace=True)

# %%
df.shape
# Out:
# (9994, 19)

# %%
df['Income'].describe()
# Out:
# count      9994.000000
# mean      39710.411833
# std       27861.200412
# min         348.670000
# 25%       19219.835000
# 50%       33156.205000
# 75%       53226.895000
# max      196746.000000
# Name: Income, dtype: float64

# %%
df.drop(df[df['Population'] > 100000].index, inplace=True)

# %%
df.shape
# Out:
# (9991, 19)

# %%
df['Population'].describe()
# Out:
# count     9991.000000
# mean      9730.486037
# std      14341.542493
# min          0.000000
# 25%        737.500000
# 50%       2905.000000
# 75%      13161.000000
# max      98660.000000
# Name: Population, dtype: float64

# %% [markdown]
# # **RE-EXPRESS CATEGORICAL DATA**

# %%
df.dtypes
# Out:
# Population                int64
# Age                       int64
# Income                  float64
# Churn                    object
# Outage_sec_perweek      float64
# Yearly_equip_failure      int64
# Techie                   object
# Port_modem               object
# Tablet                   object
# InternetService          object
# Phone                    object
# Multiple                 object
# OnlineSecurity           object
# OnlineBackup             object
# StreamingTV              object
# StreamingMovies          object
# Tenure                  float64
# MonthlyCharge           float64
# Bandwidth_GB_Year       float64
# dtype: object

# %% [markdown]
# ## **ORDINAL ENCODING**
# - encode all yes/no responses to Yes = 1 and No = 0
# - variables: Churn, Techie, Port_modem, Tablet, Phone, Multiple, OnlineSecurity, OnlineBackup, StreamingTV, StreamingMovies

# %%
df['Churn'].replace({'No' : 0, 'Yes' : 1}, inplace=True)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    7341
# 1    2650
# Name: count, dtype: int64

# %%
df['Techie'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['Port_modem'].replace({'No' : 0, 'Yes' : 1}, inplace=True)

# %%
df['Tablet'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['Phone'].replace({'No' : 0, 'Yes' : 1}, inplace=True)

# %%
df['Multiple'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['OnlineSecurity'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['OnlineBackup'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['StreamingTV'].replace({'No' : 0, 'Yes' : 1}, inplace=True)
df['StreamingMovies'].replace({'No' : 0, 'Yes' : 1}, inplace=True)

# %%
df['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# 0    5104
# 1    4887
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Population                int64
# Age                       int64
# Income                  float64
# Churn                     int64
# Outage_sec_perweek      float64
# Yearly_equip_failure      int64
# Techie                    int64
# Port_modem                int64
# Tablet                    int64
# InternetService          object
# Phone                     int64
# Multiple                  int64
# OnlineSecurity            int64
# OnlineBackup              int64
# StreamingTV               int64
# StreamingMovies           int64
# Tenure                  float64
# MonthlyCharge           float64
# Bandwidth_GB_Year       float64
# dtype: object

# %% [markdown]
# ## **ONE HOT ENCODER**
# - nomial data type: "InternetService"

# %%
df['InternetService'].unique()
# Out:
# array(['Fiber Optic', 'DSL', nan], dtype=object)

# %%
df = pd.get_dummies(df, columns=['InternetService'])

# %%
df.head()
# Out:
#    Population  Age    Income  Churn  Outage_sec_perweek  Yearly_equip_failure
# 0          38   68  28561.99      0            7.978323                     1  \
# 1       10446   27  21704.77      1           11.699080                     1
# 2        3735   50   9609.57      0           10.752800                     1
# 3       13863   48  18925.23      0           14.913540                     0
# 4       11352   83  40074.19      1            8.147417                     1
#
#    Techie  Port_modem  Tablet  Phone  Multiple  OnlineSecurity  OnlineBackup
# 0       0           1       1      1         0               1             1  \
# 1       1           0       1      1         1               1             0
# 2       1           1       0      1         1               0             0
# 3       1           0       0      1         0               1             0
# 4       0           1       0      0         0               0             0
#
#    StreamingTV  StreamingMovies     Tenure  MonthlyCharge  Bandwidth_GB_Year
# 0            0                1   6.795513     172.455519         904.536110  \
# 1            1                1   1.156681     242.632554         800.982766
# 2            0                1  15.754144     159.947583        2054.706961
# 3            1                0  17.087227     119.956840        2164.579412
# 4            1                0   1.670972     149.948316         271.493436
#
#    InternetService_DSL  InternetService_Fiber Optic
# 0                False                         True
# 1                False                         True
# 2                 True                        False
# 3                 True                        False
# 4                False                         True

# %% [markdown]
# # **DESCRIPTIVE STATISTICS**

# %%
df.describe()
# Out:
#          Population          Age         Income        Churn
# count   9991.000000  9991.000000    9991.000000  9991.000000  \
# mean    9730.486037    53.082174   39715.501730     0.265239
# std    14341.542493    20.702085   27863.826217     0.441482
# min        0.000000    18.000000     348.670000     0.000000
# 25%      737.500000    35.000000   19214.740000     0.000000
# 50%     2905.000000    53.000000   33168.880000     0.000000
# 75%    13161.000000    71.000000   53227.795000     1.000000
# max    98660.000000    89.000000  196746.000000     1.000000
#
#        Outage_sec_perweek  Yearly_equip_failure       Techie   Port_modem
# count         9991.000000           9991.000000  9991.000000  9991.000000  \
# mean            10.002278              0.397157     0.167851     0.483735
# std              2.976494              0.633253     0.373753     0.499760
# min              0.099747              0.000000     0.000000     0.000000
# 25%              8.019310              0.000000     0.000000     0.000000
# 50%             10.019720              0.000000     0.000000     0.000000
# 75%             11.971418              1.000000     0.000000     1.000000
# max             21.207230              4.000000     1.000000     1.000000
#
#             Tablet        Phone     Multiple  OnlineSecurity  OnlineBackup
# count  9991.000000  9991.000000  9991.000000     9991.000000   9991.000000  \
# mean      0.298769     0.906616     0.460815        0.357622      0.450606
# std       0.457741     0.290984     0.498487        0.479324      0.497579
# min       0.000000     0.000000     0.000000        0.000000      0.000000
# 25%       0.000000     1.000000     0.000000        0.000000      0.000000
# 50%       0.000000     1.000000     0.000000        0.000000      0.000000
# 75%       1.000000     1.000000     1.000000        1.000000      1.000000
# max       1.000000     1.000000     1.000000        1.000000      1.000000
#
#        StreamingTV  StreamingMovies       Tenure  MonthlyCharge
# count  9991.000000      9991.000000  9991.000000    9991.000000  \
# mean      0.492743         0.489140    34.508248     172.618895
# std       0.499972         0.499907    26.442933      42.937793
# min       0.000000         0.000000     1.000259      79.978860
# 25%       0.000000         0.000000     7.916107     139.979239
# 50%       0.000000         0.000000    33.196120     167.484700
# 75%       1.000000         1.000000    61.473295     200.165200
# max       1.000000         1.000000    71.999280     290.160419
#
#        Bandwidth_GB_Year
# count        9991.000000
# mean         3390.795380
# std          2185.252241
# min           155.506715
# 25%          1236.046551
# 50%          3260.745232
# 75%          5584.704954
# max          7158.981530

# %%
df['Bandwidth_GB_Year'].describe()
# Out:
# count    9991.000000
# mean     3390.795380
# std      2185.252241
# min       155.506715
# 25%      1236.046551
# 50%      3260.745232
# 75%      5584.704954
# max      7158.981530
# Name: Bandwidth_GB_Year, dtype: float64

# %%
df['Population'].describe()
# Out:
# count     9991.000000
# mean      9730.486037
# std      14341.542493
# min          0.000000
# 25%        737.500000
# 50%       2905.000000
# 75%      13161.000000
# max      98660.000000
# Name: Population, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    9991.000000
# mean       53.082174
# std        20.702085
# min        18.000000
# 25%        35.000000
# 50%        53.000000
# 75%        71.000000
# max        89.000000
# Name: Age, dtype: float64

# %%
df['Income'].describe()
# Out:
# count      9991.000000
# mean      39715.501730
# std       27863.826217
# min         348.670000
# 25%       19214.740000
# 50%       33168.880000
# 75%       53227.795000
# max      196746.000000
# Name: Income, dtype: float64

# %%
df['Outage_sec_perweek'].describe()
# Out:
# count    9991.000000
# mean       10.002278
# std         2.976494
# min         0.099747
# 25%         8.019310
# 50%        10.019720
# 75%        11.971418
# max        21.207230
# Name: Outage_sec_perweek, dtype: float64

# %%
df['Yearly_equip_failure'].describe()
# Out:
# count    9991.000000
# mean        0.397157
# std         0.633253
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         4.000000
# Name: Yearly_equip_failure, dtype: float64

# %%
df['Tenure'].describe()
# Out:
# count    9991.000000
# mean       34.508248
# std        26.442933
# min         1.000259
# 25%         7.916107
# 50%        33.196120
# 75%        61.473295
# max        71.999280
# Name: Tenure, dtype: float64

# %%
df['MonthlyCharge'].describe()
# Out:
# count    9991.000000
# mean      172.618895
# std        42.937793
# min        79.978860
# 25%       139.979239
# 50%       167.484700
# 75%       200.165200
# max       290.160419
# Name: MonthlyCharge, dtype: float64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    7341
# 1    2650
# Name: count, dtype: int64

# %%
df['Techie'].value_counts()
# Out:
# Techie
# 0    8314
# 1    1677
# Name: count, dtype: int64

# %%
df['Port_modem'].value_counts()
# Out:
# Port_modem
# 0    5158
# 1    4833
# Name: count, dtype: int64

# %%
df['Tablet'].value_counts()
# Out:
# Tablet
# 0    7006
# 1    2985
# Name: count, dtype: int64

# %%
df['Phone'].value_counts()
# Out:
# Phone
# 1    9058
# 0     933
# Name: count, dtype: int64

# %%
df['Multiple'].value_counts()
# Out:
# Multiple
# 0    5387
# 1    4604
# Name: count, dtype: int64

# %%
df['OnlineSecurity'].value_counts()
# Out:
# OnlineSecurity
# 0    6418
# 1    3573
# Name: count, dtype: int64

# %%
df['OnlineBackup'].value_counts()
# Out:
# OnlineBackup
# 0    5489
# 1    4502
# Name: count, dtype: int64

# %%
df['StreamingTV'].value_counts()
# Out:
# StreamingTV
# 0    5068
# 1    4923
# Name: count, dtype: int64

# %%
df['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# 0    5104
# 1    4887
# Name: count, dtype: int64

# %%
df['InternetService_Fiber Optic'].value_counts()
# Out:
# InternetService_Fiber Optic
# False    5587
# True     4404
# Name: count, dtype: int64

# %%
df['InternetService_DSL'].value_counts()
# Out:
# InternetService_DSL
# False    6532
# True     3459
# Name: count, dtype: int64

# %%
df[['InternetService_Fiber Optic', 'InternetService_DSL']].dtypes
# Out:
# InternetService_Fiber Optic    bool
# InternetService_DSL            bool
# dtype: object

# %%
internet = df[['InternetService_Fiber Optic', 'InternetService_DSL']]
internet.head()
# Out:
#    InternetService_Fiber Optic  InternetService_DSL
# 0                         True                False
# 1                         True                False
# 2                        False                 True
# 3                        False                 True
# 4                         True                False

# %%
internet.describe()
# Out:
#        InternetService_Fiber Optic InternetService_DSL
# count                         9991                9991
# unique                           2                   2
# top                          False               False
# freq                          5587                6532

# %%
internet.dtypes
# Out:
# InternetService_Fiber Optic    bool
# InternetService_DSL            bool
# dtype: object

# %%
internet.astype('category')
# Out:
#      InternetService_Fiber Optic InternetService_DSL
# 0                           True               False
# 1                           True               False
# 2                          False                True
# 3                          False                True
# 4                           True               False
# ...                          ...                 ...
# 9995                       False                True
# 9996                        True               False
# 9997                        True               False
# 9998                        True               False
# 9999                        True               False
#
# [9991 rows x 2 columns]

# %%
df[['InternetService_Fiber Optic', 'InternetService_DSL']].dtypes
# Out:
# InternetService_Fiber Optic    bool
# InternetService_DSL            bool
# dtype: object

# %%
df['InternetService_Fiber Optic'].dtypes
# Out:
# dtype('int64')

# %%
df['InternetService_DSL'].dtypes
# Out:
# dtype('int64')

# %%
df['InternetService_DSL'].replace({
    False : 0, 
    True : 1
}, inplace=True)

# %%
df['InternetService_DSL']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: InternetService_DSL, Length: 9991, dtype: int64

# %%
df['InternetService_Fiber Optic'].replace({
    False : 0, 
    True : 1
}, inplace=True)

# %%
df['InternetService_Fiber Optic']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: InternetService_Fiber Optic, Length: 9991, dtype: int64

# %%
df.head()
# Out:
#    Population  Age    Income  Churn  Outage_sec_perweek  Yearly_equip_failure
# 0          38   68  28561.99      0            7.978323                     1  \
# 1       10446   27  21704.77      1           11.699080                     1
# 2        3735   50   9609.57      0           10.752800                     1
# 3       13863   48  18925.23      0           14.913540                     0
# 4       11352   83  40074.19      1            8.147417                     1
#
#    Techie  Port_modem  Tablet  Phone  Multiple  OnlineSecurity  OnlineBackup
# 0       0           1       1      1         0               1             1  \
# 1       1           0       1      1         1               1             0
# 2       1           1       0      1         1               0             0
# 3       1           0       0      1         0               1             0
# 4       0           1       0      0         0               0             0
#
#    StreamingTV  StreamingMovies     Tenure  MonthlyCharge  Bandwidth_GB_Year
# 0            0                1   6.795513     172.455519         904.536110  \
# 1            1                1   1.156681     242.632554         800.982766
# 2            0                1  15.754144     159.947583        2054.706961
# 3            1                0  17.087227     119.956840        2164.579412
# 4            1                0   1.670972     149.948316         271.493436
#
#    InternetService_DSL  InternetService_Fiber Optic
# 0                    0                            1
# 1                    0                            1
# 2                    1                            0
# 3                    1                            0
# 4                    0                            1

# %%
df.to_csv('prepared_dataset_churn_D208.csv', index=False)

# %%
df['InternetService_Fiber Optic'].value_counts()
# Out:
# InternetService_Fiber Optic
# 0    5587
# 1    4404
# Name: count, dtype: int64

# %%
df['InternetService_DSL'].value_counts()
# Out:
# InternetService_DSL
# 0    6532
# 1    3459
# Name: count, dtype: int64

# %% [markdown]
# # **VISUALIZATIONS**

# %%
sns.boxplot(x='Bandwidth_GB_Year', data=df, showmeans=True)
# Out:
# <Axes: xlabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Bandwidth_GB_Year', data=df)
# Out:
# <Axes: xlabel='Bandwidth_GB_Year', ylabel='Count'>

# %%
sns.regplot(x='Bandwidth_GB_Year', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Bandwidth_GB_Year', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Population', data=df)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.regplot(x='Population', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Population', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Age', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.regplot(x='Age', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Age', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Income', data=df)
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.regplot(x='Income', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Income', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Outage_sec_perweek', data=df)
# Out:
# <Axes: xlabel='Outage_sec_perweek', ylabel='Count'>

# %%
sns.regplot(x='Outage_sec_perweek', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Outage_sec_perweek', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Yearly_equip_failure', data=df)
# Out:
# <Axes: xlabel='Yearly_equip_failure', ylabel='Count'>

# %%
sns.regplot(x='Yearly_equip_failure', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Yearly_equip_failure', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='Tenure', data=df)
# Out:
# <Axes: xlabel='Tenure', ylabel='Count'>

# %%
sns.regplot(x='Tenure', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Tenure', ylabel='Bandwidth_GB_Year'>

# %%
sns.histplot(x='MonthlyCharge', data=df)
# Out:
# <Axes: xlabel='MonthlyCharge', ylabel='Count'>

# %%
sns.regplot(x='MonthlyCharge', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='MonthlyCharge', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Churn', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.regplot(x='Churn', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Churn', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Techie', data=df)
# Out:
# <Axes: xlabel='Techie', ylabel='count'>

# %%
sns.regplot(x='Techie', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Techie', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Port_modem', data=df)
# Out:
# <Axes: xlabel='Port_modem', ylabel='count'>

# %%
sns.regplot(x='Port_modem', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Port_modem', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Tablet', data=df)
# Out:
# <Axes: xlabel='Tablet', ylabel='count'>

# %%
sns.regplot(x='Tablet', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Tablet', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='InternetService_DSL', data=df)
# Out:
# <Axes: xlabel='InternetService_DSL', ylabel='count'>

# %%
sns.countplot(x='InternetService_Fiber Optic', data=df)
# Out:
# <Axes: xlabel='InternetService_Fiber Optic', ylabel='count'>

# %%
sns.regplot(x='InternetService_DSL', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='InternetService_DSL', ylabel='Bandwidth_GB_Year'>

# %%
sns.regplot(x='InternetService_Fiber Optic', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='InternetService_Fiber Optic', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Phone', data=df)
# Out:
# <Axes: xlabel='Phone', ylabel='count'>

# %%
sns.regplot(x='Phone', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Phone', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='Multiple', data=df)
# Out:
# <Axes: xlabel='Multiple', ylabel='count'>

# %%
sns.regplot(x='Multiple', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='Multiple', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='OnlineSecurity', data=df)
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %%
sns.regplot(x='OnlineSecurity', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='OnlineBackup', data=df)
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %%
sns.regplot(x='OnlineBackup', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='StreamingTV', data=df)
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %%
sns.regplot(x='StreamingTV', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='StreamingTV', ylabel='Bandwidth_GB_Year'>

# %%
sns.countplot(x='StreamingMovies', data=df)
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %%
sns.regplot(x='StreamingMovies', y='Bandwidth_GB_Year', data=df, color='red', ci=None)
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='Bandwidth_GB_Year'>
